# %% [markdown]
# # Training Data

# %% [markdown]
# ### Objectives:
# 1. Gather Data from the sensors (1000 iterations)
# 2. Save it to a file (csv, pkl, you pick)
# 3. Plot the gathered data
# 4. Put values gathered to numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('clean_air_v.csv')
df.columns = ['MQ135', 'MQ3', 'MQ2', 'MQ4']
df
# Out:
#        MQ135      MQ3      MQ2      MQ4
# 0    0.70415  1.85143  2.83184  1.96781
# 1    0.71390  1.85081  2.83184  1.96781
# 2    0.71352  1.85068  2.83059  1.96756
# 3    0.71402  1.85081  2.83109  1.96794
# 4    0.71440  1.85068  2.83184  1.96806
# 5    0.71377  1.85093  2.83171  1.96806
# 6    0.71402  1.85043  2.83184  1.96819
# 7    0.71377  1.85068  2.83159  1.96719
# 8    0.71415  1.85043  2.83121  1.96756
# 9    0.71402  1.85031  2.83084  1.96706
# 10   0.71315  1.85031  2.83121  1.96719
# 11   0.71390  1.85081  2.83171  1.96756
# 12   0.71390  1.85031  2.83171  1.96794
# 13   0.71352  1.84968  2.83084  1.96744
# 14   0.71390  1.85031  2.81609  1.96731
# 15   0.71365  1.85031  2.83059  1.96756
# 16   0.71402  1.85056  2.83134  1.96744
# 17   0.71390  1.85043  2.83134  1.96769
# 18   0.71365  1.84943  2.83146  1.96731
# 19   0.71340  1.85006  2.83134  1.96756
# 20   0.71352  1.85018  2.83071  1.96669
# 21   0.71315  1.84993  2.83109  1.96719
# ...

# %%
df.describe()
# Out:
#             MQ135         MQ3         MQ2         MQ4
# count  999.000000  999.000000  999.000000  999.000000
# mean     0.711355    1.847637    2.833249    1.968203
# std      0.002115    0.003218    0.003605    0.002488
# min      0.702150    1.828310    2.797590    1.943060
# 25%      0.709770    1.845560    2.831590    1.967060
# 50%      0.712020    1.848560    2.833710    1.968060
# 75%      0.712770    1.849810    2.834840    1.969560
# max      0.717150    1.858810    2.845840    1.978190

# %%
df.plot()

# %% [markdown]
# ## PCA Analysis

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
sensors = ['MQ135', 'MQ3', 'MQ2', 'MQ4']
x = df.loc[:, sensors].values

# %%
x = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = x, columns= sensors).head()
# Out:
#       MQ135       MQ3       MQ2       MQ4
# 0 -3.408034  1.179527 -0.390974 -0.157962
# 1  1.204018  0.986746 -0.390974 -0.157962
# 2  1.024266  0.946324 -0.737930 -0.258480
# 3  1.260781  0.986746 -0.599147 -0.105693
# 4  1.440533  0.946324 -0.390974 -0.057445

# %%
pca = PCA(n_components=2)

# %%
components = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data=components, columns=['pc1', 'pc2'])

# %%
principalDf.head(5)
# Out:
#         pc1       pc2
# 0  1.371119  0.375991
# 1 -1.240682  0.748660
# 2 -1.035373  1.072235
# 3 -1.285212  0.930885
# 4 -1.403860  0.731488

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)


targets = ['Clean Air']
colors = ['b']
ax.scatter(principalDf.loc[:, 'pc1']
           , principalDf.loc[:, 'pc2']
           , c = 'b'
           , s = 50)
ax.legend(targets)
ax.grid()
