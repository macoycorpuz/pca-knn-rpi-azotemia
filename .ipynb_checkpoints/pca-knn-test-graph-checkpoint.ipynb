# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
def pca_graph(N, sensor_values, df):
    pca = PCA(n_components=N)
    components = pca.fit_transform(sensor_values)
    principalDf = pd.DataFrame(data=components, columns=['pc1', 'pc2'])
    finalDf = pd.concat([principalDf, df[['target']]], axis = 1)


    fig, ax= plt.subplots()
    ax.set_xlabel('PC 1', fontsize = 10)
    ax.set_ylabel('PC 2', fontsize = 10)
    targets = ['healthy', 'azotemic', 'healthy-test', 'azotemic-test']
    colors = ['g', 'r', 'b', 'y']
    for target, color in zip(targets,colors):
        indicesToKeep = finalDf['target'] == target
        ax.scatter(finalDf.loc[indicesToKeep, 'pc1'], finalDf.loc[indicesToKeep, 'pc2'], c = color, s = 50)
    ax.legend(targets)
    ax.grid()
    plt.xlim(-5, 5)
    plt.ylim(-3, 3)
    plt.show()
    return finalDf

# %%
def knn(N, X_train, X_test, y_train):
    #Feature Scaling
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    #Training and Prediction
    classifier = KNeighborsClassifier(n_neighbors=N)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    return classifier, y_pred

# %%
sensors = ['MQ2','MQ3','MQ4','MQ6','MQ7','MQ8','MQ135']
df = pd.read_csv('_dataset.csv', error_bad_lines=False)
val = df.loc[:, sensors].values
val = StandardScaler().fit_transform(val)
pcaDf = pca_graph(2, val, df)

# %%
# testDf['target'].replace(['healthy-test'], 'healthy')
# testDf['target'].replace(['azotemic-test'], 'azotemic')
dataTrain = (df['target'] == 'healthy') | (df['target'] == 'azotemic')
dataTest = (df['target'] == 'healthy-test') | (df['target'] == 'azotemic-test')
trainDf = pcaDf.loc[data]
testDf = pcaDf.loc[data]
# X_train = trainDf.iloc[:, :-1].values
# y_train = trainDf.iloc[:, 2].values
# X_test = testDf.iloc[:, :-1].values
# y_test = testDf.iloc[:, 2].values
# Out:
#           pc1       pc2    target
# 0   -2.460759  1.076854   healthy
# 1   -2.741216  1.759544   healthy
# 2   -2.406825  1.097756   healthy
# 3   -2.709100  1.472392   healthy
# 4   -2.401692  0.366127   healthy
# ..        ...       ...       ...
# 333  3.310761  0.298105  azotemic
# 334  3.516478 -0.157407  azotemic
# 335  3.758070  0.127667  azotemic
# 337  3.562005  0.036602  azotemic
# 338  3.610106 -0.430335  azotemic
#
# [309 rows x 3 columns]

# %%
classifier, y_pred = knn(5, X_train, X_test, y_train)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[211,   0],
#        [  0,  98]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     azotemic       1.00      1.00      1.00       211
#      healthy       1.00      1.00      1.00        98
#
#     accuracy                           1.00       309
#    macro avg       1.00      1.00      1.00       309
# weighted avg       1.00      1.00      1.00       309
