# %% [markdown]
# # Data Preparation

# %% [markdown]
# <b>Step 1:</b> Initialize libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# <b>Step 2:</b> Read file using pandas

# %%
df = pd.read_csv('dataset.csv')
df.columns = ['MQ135', 'MQ3', 'MQ2', 'MQ4','target']
df
# Out:
#        MQ135      MQ3      MQ2      MQ4 target
# 0    0.70415  1.85143  2.83184  1.96781    air
# 1    0.71390  1.85081  2.83184  1.96781    air
# 2    0.71352  1.85068  2.83059  1.96756    air
# 3    0.71402  1.85081  2.83109  1.96794    air
# 4    0.71440  1.85068  2.83184  1.96806    air
# 5    0.71377  1.85093  2.83171  1.96806    air
# 6    0.71402  1.85043  2.83184  1.96819    air
# 7    0.71377  1.85068  2.83159  1.96719    air
# 8    0.71415  1.85043  2.83121  1.96756    air
# 9    0.71402  1.85031  2.83084  1.96706    air
# 10   0.71315  1.85031  2.83121  1.96719    air
# 11   0.71390  1.85081  2.83171  1.96756    air
# 12   0.71390  1.85031  2.83171  1.96794    air
# 13   0.71352  1.84968  2.83084  1.96744    air
# 14   0.71390  1.85031  2.81609  1.96731    air
# 15   0.71365  1.85031  2.83059  1.96756    air
# 16   0.71402  1.85056  2.83134  1.96744    air
# 17   0.71390  1.85043  2.83134  1.96769    air
# 18   0.71365  1.84943  2.83146  1.96731    air
# ...

# %%
df.describe()
# Out:
#             MQ135         MQ3         MQ2         MQ4
# count  999.000000  999.000000  999.000000  999.000000
# mean     0.711355    1.847637    2.833249    1.968203
# std      0.002115    0.003218    0.003605    0.002488
# min      0.702150    1.828310    2.797590    1.943060
# 25%      0.709770    1.845560    2.831590    1.967060
# 50%      0.712020    1.848560    2.833710    1.968060
# 75%      0.712770    1.849810    2.834840    1.969560
# max      0.717150    1.858810    2.845840    1.978190

# %%
df.plot()

# %% [markdown]
# # PCA Analysis Visualization

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
sensors = ['MQ135', 'MQ3', 'MQ2', 'MQ4']
sensor_values = df.loc[:, sensors].values

# %%
target_values = df.loc[:,['target']].values

# %%
sensor_values = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = sensor_values, columns= sensors).head()
# Out:
#       MQ135       MQ3       MQ2       MQ4
# 0 -3.408034  1.179527 -0.390974 -0.157962
# 1  1.204018  0.986746 -0.390974 -0.157962
# 2  1.024266  0.946324 -0.737930 -0.258480
# 3  1.260781  0.986746 -0.599147 -0.105693
# 4  1.440533  0.946324 -0.390974 -0.057445

# %%
pca = PCA(n_components=2)

# %%
components = pca.fit_transform(sensor_values)

# %%
principalDf = pd.DataFrame(data=components, columns=['pc1', 'pc2'])
principalDf.head(5)
# Out:
#         pc1       pc2
# 0  1.371119  0.375991
# 1 -1.240682  0.748660
# 2 -1.035373  1.072235
# 3 -1.285212  0.930885
# 4 -1.403860  0.731488

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)
finalDf.head(5)
# Out:
#         pc1       pc2 target
# 0  1.371119  0.375991    air
# 1 -1.240682  0.748660    air
# 2 -1.035373  1.072235    air
# 3 -1.285212  0.930885    air
# 4 -1.403860  0.731488    air

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)


targets = ['air']
colors = ['b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'pc1']
               , finalDf.loc[indicesToKeep, 'pc2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# # Train and Test Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# test_size: what proportion of original data is used for test set
train_set, test_set, train_lbl, test_lbl = train_test_split(sensor_values, target_values, test_size=1/7.0, random_state=0)

# %%
scaler = StandardScaler()

# Fit on training set only.
scaler.fit(train_set)

# Apply transform to both the training set and the test set.
train_set = scaler.transform(train_set)
test_set = scaler.transform(test_set)

# %%
pca = PCA(.95)
pca.fit(train_set)
pca.n_components_
train_set = pca.transform(train_set)
test_set = pca.transform(test_set)

# %%
logisticRegr = LogisticRegression(solver = 'lbfgs')
logisticRegr.fit(train_set, train_lbl)
# Out:
# /Users/oghcorpuz/thesis/env/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-0475f1bb694d> in <module>
#       1 logisticRegr = LogisticRegression(solver = 'lbfgs')
# ----> 2 logisticRegr.fit(train_set, train_lbl)
#
# ~/thesis/env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1561             raise ValueError("This solver needs samples of at least 2 classes"
#    1562                              " in the data, but the data contains only one"
# -> 1563                              " class: %r" % classes_[0])
#    1564
# ...
